# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
Base_URL = "https://news.abs-cbn.com/list/tag/tfc-news?page="
PageNumber = 1
NumPages

DateMonth = "Mar" # Must be 3 letters (Jan, Feb, Mar, Apr)
DateFrom = 11
DateTo = 12
SearchedAuthor = "None" # Add string of author name if also searching by author

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64'}
page = requests.get("".join((Base_URL, str(PageNumber))), headers = headers)
soup = BeautifulSoup(page.content, 'html.parser')
news_content = soup.find("section", class_ = "section-more-stories")
news_list = news_content.find_all("article")

# %%
all_articles = []

for PageNumber in NumPages:
    page = requests.get("".join((Base_URL, str(PageNumber))), headers = headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    news_content = soup.find("section", class_ = "section-more-stories")
    news_list = news_content.find_all("article")

    for ctr in range(len(news_list)):
        article = {}

        date = news_list[ctr].find("span", class_="datetime").text
        title = news_list[ctr].find("p", class_="title").text
        full_article = "".join(("https://news.abs-cbn.com", news_list[ctr].find("a").get("href")))
        author = news_list[ctr].find("span", class_="author").text.split(" |")[0]
        
        if SearchedAuthor is None:
            if date[0:3] == DateMonth and int(date[4:6]) <= DateTo and int(date[4:6]) >= DateFrom:
                article = {
                    "Date and Time": date,
                    "Title": title,
                    "Full Article": full_article,
                    "Author": author
                }

                all_articles.append(article)
        else:
            if SearchedAuthor == author and date[0:3] == DateMonth and int(date[4:6]) <= DateTo and int(date[4:6]) >= DateFrom:
                article = {
                    "Date and Time": date,
                    "Title": title,
                    "Full Article": full_article,
                    "Author": author
                }

                all_articles.append(article)
    
all_articles
# Out:
# []

# %%
with open('esquivel_chua_api.json', 'w') as fp:
    json.dump(all_articles, fp, indent = 4)

# %%
jsonFile = pd.read_json("esquivel_chua_api.json", orient = "records")
print(jsonFile)
# Out:
#      Date and Time                                              Title  \
# 0  Mar 12 06:50 PM  Libreng tableta ipinamimigay sa Belgium sa git...
# 1  Mar 12 06:04 PM  Social media apps, ilang western sites blocked...
# 2  Mar 12 04:57 PM  Health cooperation sa pagitan ng Pilipinas at ...
# 3  Mar 12 04:10 PM  PH Embassy, Royal Thai Embassy nagtulungan sa ...
# 4  Mar 12 02:56 PM  Tatlong grupo ng Pinoy evacuees mula Ukraine n...
# 5  Mar 12 02:56 AM  Gigi De Lana at Gigi Vibes nasa Dubai na, fans...
# 6  Mar 11 03:52 PM  Alex Mallari Jr. highlights PH background in '...
# 7  Mar 11 01:53 AM  COVID Memorial Wall sa London dinarayo; mga ba...
# 8  Mar 11 01:45 PM      Pinoy exhibit “Guerra,” ibinida sa Barcelona
#
#                                         Full Article                    Author
# 0  https://news.abs-cbn.com/news/03/12/22/libreng...  Raquel Bernal Crisostomo
# 1  https://news.abs-cbn.com/news/03/12/22/social-...        Niel Caburnay Tero
# 2  https://news.abs-cbn.com/news/03/12/22/health-...         Jerome Fadriquela
# 3  https://news.abs-cbn.com/news/03/12/22/ph-emba...         Jerome Fadriquela
# 4  https://news.abs-cbn.com/news/03/12/22/tatlong...         Jerome Fadriquela
# 5  https://news.abs-cbn.com/news/03/12/22/gigi-de...              Randy Lamsen
# 6  https://news.abs-cbn.com/entertainment/03/11/2...               Yong Chavez
# 7  https://news.abs-cbn.com/news/03/11/22/covid-m...            Rose Eclarinal
# 8  https://news.abs-cbn.com/news/03/11/22/pinoy-e...        Sandra Sotelo-Aboy
